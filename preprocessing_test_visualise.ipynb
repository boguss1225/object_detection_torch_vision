# %%
FILE_PATH = "/home/hemyo/Desktop/1_data/3_Annoatation_data/2_9frame_interval_cropped/MED2017/EU-MLT-011-FF/"
FILE_PATH = FILE_PATH+ "20170612_145403_00111CF01807_EU-MLT-011_FF_Left_1281.png"

# %%
import cv2
import matplotlib.pyplot as plt
im_orig = cv2.imread(FILE_PATH)
im_gray = cv2.imread(FILE_PATH, cv2.IMREAD_GRAYSCALE)
# cv2.imwrite('blackwhite.png', im_gray)
plt.imshow(im_gray)

# %%
plt.imshow(im_orig)

# %%
im_gray.shape
# Out:
# (1040, 1392)

# %%
im_orig.shape
# Out:
# (1040, 1392, 3)

# %%
sobelxy = cv2.Sobel(src=im_orig, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_11286/1648910420.py in <module>
#       1 # sobelx = cv2.Sobel(src=im_gray, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
#       2 # sobely = cv2.Sobel(src=im_gray, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
# ----> 3 sobelxy = cv2.Sobel(src=im_orig, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=4) # Combined X and Y Sobel Edge Detection
#
# error: OpenCV(4.5.4) /tmp/pip-req-build-3129w7z7/opencv/modules/imgproc/src/deriv.cpp:104: error: (-211:One of the arguments' values is out of range) The kernel size must be odd and not larger than 31 in function 'getSobelKernels'

# %%
plt.imshow(sobelxy)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
sobelxy = cv2.Sobel(src=im_orig, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=9) #Max sobel

# %%
plt.imshow(sobelxy)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Sobel seems to generate noise... not usefull

# %%
canny = cv2.Canny(image=im_orig, threshold1=10, threshold2=90) #

# %%
plt.imshow(canny)

# %%
canny = cv2.Canny(image=im_orig, threshold1=100, threshold2=300) #

# %%
plt.imshow(canny)

# %%
# canny seems to remove details

# %%
FILE_PATH = "/home/hemyo/Desktop/1_data/5_crooped_fish/v1_bbox_refined/1_cropped/train/"
FILE_PATH = FILE_PATH + "20210708_091943977_220309_MLT2021AUTCG031_EUMLT011FF_right_1012_2.png"
# FILE_PATH = FILE_PATH + "20210708_091943977_220310_MLT2021AUTCG031_EUMLT011FF_left_951.png"

# %%
im_orig = cv2.imread(FILE_PATH)
im_gray = cv2.imread(FILE_PATH, cv2.IMREAD_GRAYSCALE)

# %%
sobelxy = cv2.Sobel(src=im_orig, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=9) #Max sobel

# %%
plt.imshow(sobelxy)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
canny = cv2.Canny(image=im_orig, threshold1=50, threshold2=200) #

# %%
plt.imshow(canny)
